# %%
import requests
import pandas as pd
import geopandas as gpd

# %%
base_url = "http://environment.data.gov.uk/flood-monitoring/id/stations/E20024/readings"
#stations_url = "http://environment.data.gov.uk/flood-monitoring/id/stations"

# %%
params = {
    #"parameter": "level",              # Request data for water level
    # "qualifier": "stage",              # Specify "stage" as the qualifier
    "since": "2024-06-20",   # Start date from 2020 in ISO format
    "_limit": 1000,                      # Set a higher limit for the number of records
    "_view": "full"
}

# Make the request
response = requests.get(base_url.format(station_id=station_id), params=params)
print(response.text)
# Out:
# {
#   "@context" : "http://environment.data.gov.uk/flood-monitoring/meta/context.jsonld" ,
#   "meta" : {
#     "publisher" : "Environment Agency" ,
#     "licence" : "http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" ,
#     "documentation" : "http://environment.data.gov.uk/flood-monitoring/doc/reference" ,
#     "version" : "0.9" ,
#     "comment" : "Status: Beta service" ,
#     "hasFormat" : [ "http://environment.data.gov.uk/flood-monitoring/id/stations/E20024/readings.csv?since=2024-06-20&_limit=1000&_view=full", "http://environment.data.gov.uk/flood-monitoring/id/stations/E20024/readings.rdf?since=2024-06-20&_limit=1000&_view=full", "http://environment.data.gov.uk/flood-monitoring/id/stations/E20024/readings.ttl?since=2024-06-20&_limit=1000&_view=full", "http://environment.data.gov.uk/flood-monitoring/id/stations/E20024/readings.html?since=2024-06-20&_limit=1000&_view=full" ] ,
#     "limit" : 1000
#   }
#    ,
#   "items" : [ {
# ...

# %%
rain_url = "http://environment.data.gov.uk/flood-monitoring/id/stations/E20024/readings"

# %%
if response.status_code == 200:
    print("Response content:", response.text)
    data = response.json()["items"]  # Assuming 'items' contains the readings data
    # Convert data to a DataFrame
    df = pd.DataFrame(data)
    # Display the DataFrame
    print(df)
else:
    print("Failed to retrieve data:", response.status_code, response.text)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
geo_path = 'Anglian water/DMA shape file/DMA.shp'
data_geo = gpd.read_file(geo_path)
data_geo
# Out:
#      NETWORKBOU    MIDPOINTGR                        DMALONGNAM DZ_SHORT_N  \
# 0      Grantham  TF0997418609               BOURNE AUSTERBY DMA   BOURNEDZ
# 1       Ipswich  TM1727947391                   WESTERFIELD DMA   PARKWBDZ
# 2          None          None                              None       None
# 3      Grantham  TF1324513086                      LANGTOFT DMA   WLSSTHDZ
# 4      Grantham  TF1086809217                  WEST DEEPING DMA   TALLPUDZ
# ...         ...           ...                               ...        ...
# 2947    Ipswich  TM2736037131  IWNL REEVE LODGE HIGH ROAD B NAV   IPSFELDZ
# 2948    Ipswich  TL8843817124                  TIPTREE WEST DMA   COLTIPDZ
# 2949   Grantham  TF2811340184                    KIRTON END DMA   SUTNRHDZ
# 2950   Grantham  SK9278729001        HARROWBY BOOSTER SOUTH DMA   HARROSDZ
# 2951       None          None                              None       None
#
# ...

# %%
import zipfile
import os

# %%
folder_path = 'Anglian water/TSD'

# %%
for file_name in os.listdir(folder_path):
    if file_name.endswith('.zip'):
        file_path = os.path.join(folder_path, file_name)
        extract_folder = os.path.join(folder_path,file_name.replace('.zip',''))
        os.makedirs(extract_folder,exist_ok=True)
        with zipfile.ZipFile(file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_folder)
            print(f'Extracted {file_name} to {extract_folder}')
# Out:
# Extracted 2020-Q1-LCC.zip to Anglian water/TSD\2020-Q1-LCC
# Extracted 2020-Q1.zip to Anglian water/TSD\2020-Q1
# Extracted 2020-Q2-LCC.zip to Anglian water/TSD\2020-Q2-LCC
# Extracted 2020-Q2.zip to Anglian water/TSD\2020-Q2
# Extracted 2020-Q3-LCC.zip to Anglian water/TSD\2020-Q3-LCC
# Extracted 2020-Q3.zip to Anglian water/TSD\2020-Q3
# Extracted 2020-Q4-LCC.zip to Anglian water/TSD\2020-Q4-LCC
# Extracted 2020-Q4.zip to Anglian water/TSD\2020-Q4
# Extracted 2021-Q1-LCC.zip to Anglian water/TSD\2021-Q1-LCC
# Extracted 2021-Q1.zip to Anglian water/TSD\2021-Q1
# Extracted 2021-Q2-LCC.zip to Anglian water/TSD\2021-Q2-LCC
# Extracted 2021-Q2.zip to Anglian water/TSD\2021-Q2
# Extracted 2021-Q3-LCC.zip to Anglian water/TSD\2021-Q3-LCC
# Extracted 2021-Q3.zip to Anglian water/TSD\2021-Q3
# Extracted 2021-Q4-LCC.zip to Anglian water/TSD\2021-Q4-LCC
# Extracted 2021-Q4.zip to Anglian water/TSD\2021-Q4
# Extracted 2022-Q1-LCC.zip to Anglian water/TSD\2022-Q1-LCC
# ...

# %%
folder_path = 'Anglian water/TSD/30 day'

# %%
for file_name in os.listdir(folder_path):
    if file_name.endswith('.zip'):
        file_path = os.path.join(folder_path, file_name)
        extract_folder = os.path.join(folder_path,file_name.replace('.zip',''))
        os.makedirs(extract_folder,exist_ok=True)
        with zipfile.ZipFile(file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_folder)
            print(f'Extracted {file_name} to {extract_folder}')
# Out:
# Extracted 2023-07-25 - 30 Day Extract.zip to Anglian water/TSD/30 day\2023-07-25 - 30 Day Extract
# Extracted 2023-08-01 - 30 Day Extract.zip to Anglian water/TSD/30 day\2023-08-01 - 30 Day Extract
# Extracted 2023-08-07 - 30 Day Extract.zip to Anglian water/TSD/30 day\2023-08-07 - 30 Day Extract
# Extracted 2023-08-14 - 30 Day Extract.zip to Anglian water/TSD/30 day\2023-08-14 - 30 Day Extract
# Extracted 2023-08-21 - 30 Day Extract.zip to Anglian water/TSD/30 day\2023-08-21 - 30 Day Extract
# Extracted 2023-08-30 - 30 Day Extract.zip to Anglian water/TSD/30 day\2023-08-30 - 30 Day Extract
# Extracted 2023-09-04 - 30 Day Extract.zip to Anglian water/TSD/30 day\2023-09-04 - 30 Day Extract
# Extracted 2023-09-13 - 30 Day Extract.zip to Anglian water/TSD/30 day\2023-09-13 - 30 Day Extract
# Extracted 2023-09-18 - 30 Day Extract.zip to Anglian water/TSD/30 day\2023-09-18 - 30 Day Extract
# Extracted 2023-09-25 - 30 Day Extract.zip to Anglian water/TSD/30 day\2023-09-25 - 30 Day Extract
# ...

# %%
folder_path = 'Anglian water/TSD/months'

# %%
for file_name in os.listdir(folder_path):
    if file_name.endswith('.zip'):
        file_path = os.path.join(folder_path, file_name)
        extract_folder = os.path.join(folder_path,file_name.replace('.zip',''))
        os.makedirs(extract_folder,exist_ok=True)
        with zipfile.ZipFile(file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_folder)
            print(f'Extracted {file_name} to {extract_folder}')
# Out:
# Extracted 2021-02.zip to Anglian water/TSD/months\2021-02
# Extracted 2021-03.zip to Anglian water/TSD/months\2021-03
# Extracted 2021-04.zip to Anglian water/TSD/months\2021-04
# Extracted 2021-05.zip to Anglian water/TSD/months\2021-05
# Extracted 2021-06.zip to Anglian water/TSD/months\2021-06
# Extracted 2021-07.zip to Anglian water/TSD/months\2021-07
# Extracted 2021-08.zip to Anglian water/TSD/months\2021-08
# Extracted 2021-09.zip to Anglian water/TSD/months\2021-09
# Extracted 2021-10.zip to Anglian water/TSD/months\2021-10
# Extracted 2021-11.zip to Anglian water/TSD/months\2021-11
# Extracted 2021-12.zip to Anglian water/TSD/months\2021-12
# Extracted 2022-01.zip to Anglian water/TSD/months\2022-01
# Extracted 2022-02.zip to Anglian water/TSD/months\2022-02
# Extracted 2022-03.zip to Anglian water/TSD/months\2022-03
# Extracted 2022-04.zip to Anglian water/TSD/months\2022-04
# Extracted 2022-05.zip to Anglian water/TSD/months\2022-05
# ...
